# %% [markdown]
# # Working with Digital Herbarium using Python

# %% [markdown]
# [Python](http://python.org) programming language is a popular tool for speaking with a computer. It is a common purpose programming language widely used not only in programming field, but also in scientific computations, data analysis and engeneering.
#
# Among reasons Python beign popular are its programming productivity, code readability, obvious simplicity, as well as dynamic typing, supporting [OOPs](https://en.wikipedia.org/wiki/Object-oriented_programming) coding style, cross-platform runability etc.
#
# When writting in Python, there are almost no chances to get unreadable code. Every block of the program is separated from others by predefined number of spaces that leads to an easy-to-read textual document. There are recommendations on how to write Python code [pep8](https://www.python.org/dev/peps/pep-0008/). Pep8 document aims at writting readable and easy understandable Python code.
#
# Reproducing computations presented below assumes Python 3.5+ to be installed in your operational system, as well some Python packages (e.g. [Pandas](http://pandas.pydata.org), [NumPy](http://numpy.org) etc.);
# To get working trough the experiments on spatially distributed data, you will need additionally to install `pyshp`  (a tool for I/O operations with ESRI shape files) and `shapely` (geometry primitives and interactions) packages.
#
# Windows users can start with [Anaconda](https://www.continuum.io/downloads) distribution. This distribution was designed to provide a convenient toolset for scientific computations and data analysis on top of Python, so it could be a good starting point in the way of building computational environment for your investigations.
#
# Executable lines of code are given in `In[xxx]`-started blocks; these blocks could be executed either in [Jupyter](http://jupyter.org/) interactive environment or by coping them into a separate text file (with `.py` extension) and running with Python interpreter.
#
# This document is created using [Jupyter](http://jupyter.org/) software, interactive environment that allows mixing code and text in pretty-styled way.

# %% [markdown]
# ## Making simple queries

# %% [markdown]
# To get started, we need to prepare computational environment. The most important component of it, is the [Pandas](http://pandas.pydata.org) package; It is highly recommmended to install it before doing any manipulation with data. Being Pandas installed, it supply us with a good and convienient data container -- the DataFrame class, that, in turn, allows to make sofphisticated data selection and perform basic input and output (IO) operations.
#
# We assume that the Pandas has been already installed. So, lets do importing it.

# %%
import pandas as pd  # This is an implicit agreement: everytime you need pandas, it is better to import it as `pd`.

# %% [markdown]
# Lets define variable called `HERBARIUM_SEARCH_URL`. This variable will point to the URI, where we will send HTTP search quieries. This URI assumed to be a permanent address, so, it probably willn't be changed in the nearest future.
#
# Note: Оne can use HTTPS protocol instead. In this case just replace `http` with `https` in `HERBARIUM_SEARCH_URL`.

# %%
HERBARIUM_SEARCH_URL = 'http://botsad.ru/hitem/json/'

# %% [markdown]
# It is worth noting that variable's naming is very important part of any programming process. One can think that it isn't so important, and would use shorthand notations instead, bearing in mind that everything will be clear, at least, for myself. But this isn't a good reason to do so, even if you are writting code just to yourself. Best practice in this case assumes to choose variable names to be clear for everyone (in an intuitive way) on the one hand, and to be as short as possible on the other.

# %% [markdown]
# Let us organize search parameters in a list of tuples, as follows
# (to get full description of all available search parameters follow through the [link](https://github.com/VBGI/herbs/blob/master/herbs/docs/httpapi/ru/http_api.rst)):

# %%
search_parameters_set = (('collectedby', 'Bakalin'),
                         ('identifiedby', 'Bakalin'),
                         ('colstart', '2016-01-01'),
                         ('colend', '2016-12-30')
                         )

# %% [markdown]
# Let's do importing necessary set of functions to make TTP-requests automatically. Python's ecosystem provides a lot of tools to do this: one can use third party packages, or just use ones included in the Python (a.k.a "battarie included" pack) standard distributive.

# %%
try:
    # Python 3.x
    from urllib.parse import quote
    from urllib.request import urlopen
except ImportError:
    # Python 2.x
    from urllib import quote
    from urllib import urlopen

# %% [markdown]
# Now, we can use defined variables to compose search URI (according to http-api [rules](https://github.com/VBGI/herbs/blob/master/herbs/docs/httpapi/en/http_api.rst)):

# %%
search_request_url = HERBARIUM_SEARCH_URL + '?' + '&'.join(map(lambda x: x[0] + '=' + quote(x[1].strip()), search_parameters_set))

# %% [markdown]
# According to the [URI specification](https://tools.ietf.org/html/rfc3986#page-11) non-ASCII characters used in the URI should be encoded using symbol '%'. So, if your query will include non-ascii chars, you will need to use helper function `quote` to do such encoding.
#
# In case of simple quieries, one can assign `search_request_url` directly, e.g.:
# ```python
# search_request_url = http://botsad.ru/hitem/json?collectedby=bakalin
# ```
#
# This way is your choice, but best practice scripting assumes that you will divide process of building the `search_request_url`. Using `search_parameters_set` allows you to be more structured and organized in case of, for instance, making complicated searching queries, performing a set of cosequent quieries with different parameter sets etc.:
#
# ```python
# list_of_search_pars = [search_parameters_set1, search_parameters_set2, search_parameters_set3,]
#
# list_of_search_urls = [search_request_url1, search_request_url2, search_request_url3, ]
# ```

# %% [markdown]
# For the sake of self-checking, one can print out the current value of the `search_request_url`.

# %%
search_request_url
# Out:
# 'http://botsad.ru/hitem/json/?collectedby=Bakalin&identifiedby=Bakalin&colstart=2016-01-01&colend=2016-12-30'

# %% [markdown]
# Now, we are ready to make searching request to the server. In general,  data loading and its transformation into Python dictionary consist of the following four lines of code:

# %%
import json
server_response = urlopen(search_request_url)
data = json.loads(server_response.read().decode('utf-8'))
server_response.close()

# %% [markdown]
# So, the variable `data` stores Python dictionary with fields defined in [official docs](https://github.com/VBGI/herbs/blob/master/herbs/docs/httpapi/en/http_api.rst).

# %% [markdown]
# Getting started the data evaluation, one should check `errors` and `warnings` fields; If everything went fine, these variables are leaved empty, or just `warnings` is non-empty.

# %%
data['errors'], data['warnings']
# Out:
# ([], [])

# %% [markdown]
# Therefore, data was successfully loaded, and we can start typical data evaluation process using [Pandas](http://pandas.pydata.org/).

# %%
print("The number of obtained records is ", len(data['data']))
# Out:
# The number of obtained records is  127

# %% [markdown]
# Now, `data['data']` is a Python dictionary; Python dictionaries are convenient containers for structured data, but Pandas DataFrame is more appropriate for this purpose.
# Let us convert the dictionary to the DataFrame object; it is quite simple:

# %%
search_df = pd.DataFrame(data['data'])

# %% [markdown]
# `search_df` is an instance of the DataFrame class, that has a lot of helper methods to get information about the data. Such of that are `.info()` and `.describe()` methods; They are used to get common information about the data.

# %%
search_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 35 columns):
# acronym                    127 non-null object
# additionals                127 non-null object
# altitude                   127 non-null object
# branch                     127 non-null object
# collection_finished        127 non-null object
# collection_started         127 non-null object
# collectors                 127 non-null object
# country                    127 non-null object
# country_id                 127 non-null int64
# created                    127 non-null object
# details                    127 non-null object
# dethistory                 127 non-null object
# devstage                   127 non-null object
# district                   127 non-null object
# family                     127 non-null object
# family_authorship          127 non-null object
# fieldid                    127 non-null object
# genus                      127 non-null object
# genus_authorship           127 non-null object
# gpsbased                   127 non-null bool
# id                         127 non-null int64
# identification_finished    127 non-null object
# identification_started     127 non-null object
# identifiers                127 non-null object
# itemcode                   127 non-null object
# latitude                   127 non-null float64
# longitude                  127 non-null float64
# note                       127 non-null object
# region                     127 non-null object
# species_authorship         127 non-null object
# species_epithet            127 non-null object
# species_fullname           127 non-null object
# species_id                 127 non-null int64
# species_status             127 non-null object
# updated                    127 non-null object
# dtypes: bool(1), float64(2), int64(3), object(29)
# memory usage: 33.9+ KB

# %% [markdown]
# Also, one can inspect your DataFrame's content:

# %%
search_df
# Out:
#     acronym                                        additionals   altitude  \
# 0      VBGI  [{'family_authorship': '', 'genus_authorship':...        124
# 1      VBGI                                                 []        810
# 2      VBGI                                                 []         24
# 3      VBGI                                                 []         81
# 4      VBGI                                                 []         81
# 5      VBGI                                                 []        810
# 6      VBGI                                                 []         24
# 7      VBGI                                                 []         81
# 8      VBGI                                                 []         81
# 9      VBGI                                                 []         24
# 10     VBGI  [{'family_authorship': '', 'genus_authorship':...         81
# 11     VBGI  [{'family_authorship': '', 'genus_authorship':...        105
# 12     VBGI  [{'family_authorship': '', 'genus_authorship':...       1570
# 13     VBGI                                                 []         74
# 14     VBGI                                                 []         74
# 15     VBGI  [{'family_authorship': '', 'genus_authorship':...        470
# 16     VBGI                                                 []        470
# 17     VBGI                                                 []       2100
# 18     VBGI                                                 []       1570
# 19     VBGI                                                 []        470
# 20     VBGI                                                 []        470
# 21     VBGI  [{'family_authorship': '', 'genus_authorship':...        470
# 22     VBGI                                                 []        470
# 23     VBGI  [{'family_authorship': '', 'genus_authorship':...        520
# 24     VBGI                                                 []        520
# 25     VBGI  [{'family_authorship': '', 'genus_authorship':...        520
# 26     VBGI  [{'family_authorship': '', 'genus_authorship':...        520
# 27     VBGI                                                 []        520
# 28     VBGI  [{'family_authorship': '', 'genus_authorship':...        520
# 29     VBGI                                                 []       1350
# ..      ...                                                ...        ...
# 97     VBGI                                                 []       3143
# 98     VBGI  [{'family_authorship': '', 'genus_authorship':...       1900
# 99     VBGI                                                 []         80
# 100    VBGI                                                 []         80
# 101    VBGI                                                 []  1700-1900
# 102    VBGI                                                 []       1900
# 103    VBGI                                                 []        600
# 104    VBGI                                                 []        600
# 105    VBGI                                                 []        600
# 106    VBGI                                                 []       1900
# 107    VBGI                                                 []        400
# 108    VBGI                                                 []  1700-1900
# 109    VBGI  [{'family_authorship': '', 'genus_authorship':...        400
# 110    VBGI                                                 []        400
# 111    VBGI                                                 []        400
# 112    VBGI                                                 []        400
# 113    VBGI  [{'family_authorship': '', 'genus_authorship':...        400
# 114    VBGI                                                 []        400
# 115    VBGI                                                 []        720
# 116    VBGI                                                 []       1900
# 117    VBGI                                                 []       3143
# 118    VBGI                                                 []        720
# 119    VBGI                                                 []        720
# 120    VBGI                                                 []       1900
# 121    VBGI                                                 []        720
# 122    VBGI                                                 []        720
# 123    VBGI                                                 []       2100
# 124    VBGI  [{'family_authorship': '', 'genus_authorship':...       1570
# 121                  V.A. Bakalin   Russia         162  2017-04-07
# 122                  V.A. Bakalin   Russia         162  2017-04-07
# 123                  V.A. Bakalin  Vietnam         134  2017-04-07
# 124                  V.A. Bakalin   Russia         162  2017-04-07
# 125                  V.A. Bakalin   Russia         162  2017-04-07
# 126                  V.A. Bakalin   Russia         162  2017-04-07
#
#         ...       latitude   longitude  \
# 0       ...      43.368000  131.638000
# 1       ...      43.109000  132.787000
# 2       ...      43.655000  131.920000
# 3       ...      43.365000  131.642000
# 4       ...      43.365000  131.642000
# 5       ...      43.099000  132.786000
# 6       ...      43.655000  131.920000
# 7       ...      43.365000  131.508000
# 8       ...      43.365000  131.642000
# 9       ...      43.655000  131.920000
# 10      ...      43.365000  131.640000
# 11      ...      44.958889  131.789722
# 12      ...      50.308056  134.664444
# 13      ...      44.644444  132.052778
# 14      ...      44.644444  132.052778
# 15      ...      44.580556  135.549444
# 16      ...      44.580556  135.549444
# 17      ...      22.338333  103.777500
# 18      ...      50.308056  134.664444
# 19      ...      44.580556  135.549444
# 20      ...      44.580556  135.549444
# 21      ...      44.580556  135.549444
# 22      ...      44.580556  135.549444
# 23      ...      44.585278  135.556111
# 24      ...      44.585278  135.556111
# 25      ...      44.585278  135.556111
# 26      ...      44.585278  135.556111
# 27      ...      44.585278  135.556111
# 28      ...      44.590000  135.560000
# 29      ...      22.403056  103.837778
# ..      ...            ...         ...
# 97      ...      22.303056  103.775278
# 98      ...      22.349000  103.767000
# 99      ...      44.570556  132.075833
# 100     ...      44.570556  132.075833
# 101     ...      22.348611  103.767500
# 102     ...      22.348611  103.767500
# 103     ...      50.261944  134.696667
# 104     ...      50.261944  134.696667
# 105     ...      50.261944  134.696667
# 106     ...      22.348611  103.767500
# 107     ...      44.833333  131.694167
# 108     ...      22.349000  103.767000
# 109     ...      44.833333  131.694167
# 110     ...      44.833333  131.694167
# 111     ...      44.833333  131.694167
# 112     ...      44.833333  131.694167
# 113     ...      44.833333  131.694167
# 114     ...      44.833333  131.694167
# 115     ...      44.862222  131.708333
# 116     ...      22.349000  103.767000
# 117     ...      22.303000  103.775000
# 118     ...      44.862222  131.708333
# 119     ...      44.862222  131.708333
# 120     ...      22.348611  103.767500
# 121     ...      44.862222  131.708333
# 122     ...      44.862222  131.708333
# 123     ...      22.338333  103.777500
# 124     ...      50.308056  134.664444
# 125     ...      44.862222  131.708333
# 126     ...      44.958889  131.789722
#
#                                                   note  \
# 0        Khasansky District, Kravtsovka Stream Valley.
# 1    Shkotovsky District, Northern slope of Falaza ...
# 2    Nadezhdensky District, Razdol’naya River Valle...
# 3        Khasansky District, Kravtsovka Stream Valley.
# 4        Khasansky District, Kravtsovka Stream Valley.
# 5    Shkotovsky District, Northern slope of Falaza ...
# 6    Nadezhdensky District, Razdol’naya River Valle...
# 7        Khasansky District, Kravtsovka Stream Valley.
# 8        Khasansky District, Kravtsovka Stream Valley.
# 9    Nadezhdensky District, Razdol’naya River Valle...
# 10        Khasansky District, Kravtsovka Stream Valley
# 11   Khankajsky District, Komissarovka River middle...
# 107                                (L.) Raddi
# 108                                    Furuki
# 109                                        L.
# 110                               R.M. Schust
# 111                                    Hoffm.
# 112                                (L.) Evans
# 113                                    Hoffm.
# 114                                      Gray
# 115                                        L.
# 116                         (S. Hatt.) Furuki
# 117
# 118                                (L.) Raddi
# 119  (Shimizu & S. Hatt.) Borovich. & Bakalin
# 120                           (Thunb.) Grolle
# 121                   (Balb.) Frye & L. Clark
# 122                   (Balb.) Frye & L. Clark
# 123                         (Austin) Stephani
# 124                           Lindb. & Arnell
# 125                                (L.) Evans
# 126                                        L.
#
#                       species_epithet  \
# 0                            erimonus
# 1                                laxa
# 2                            levigata
# 3                         leptophylla
# 4                         leptophylla
# 5      hemisphaerica subsp. australis
# 6                                nana
# 7                           japonicum
# 8                          salebrosum
# 9                          salebrosum
# 10                           paleacea
# 11                           fragrans
# 12                               nana
# 13                             natans
# 14                           fluitans
# 15                           quadrata
# 16                         salebrosum
# 17                       consanguinea
# 18                               laxa
# 19                       pterospermum
# 20                       pterospermum
# 21                       pterospermum
# 22                       pterospermum
# 23                          pubescens
# 24                           fragrans
# 25                          pubescens
# 26      hemisphaerica ssp. orientalis
# 27                                sp.
# 28                           quadrata
# 29                         subciliata
# ..                                ...
# 97                       consanguinea
# 98                            pinguis
# 99                       huebeneriana
# 100                          fluitans
# 101                       flavovirens
# 102                               sp.
# 103     hemisphaerica ssp. orientalis
# 104                        hypophylla
# 105                            pilosa
# 106                               sp.
# 107  hemisphaerica ssp. hemisphaerica
# 108                       flavovirens
# 109                        hypophylla
# 110     hemisphaerica ssp. orientalis
# 111                           bifurca
# 112                         androgyna
# 113                           bifurca
# 114                         latifolia
# 115                        hypophylla
# 116                      yakusimensis
# 117                               sp.
# 118  hemisphaerica ssp. hemisphaerica
# 119                              nana
# 120                         japonicum
# 121                          fragrans
# 122                          fragrans
# 123                        subciliata
# 124                              laxa
# 125                         androgyna
# 126                          fluitans
#
#                                       species_fullname species_id  \
# 0    Hattorianthus erimonus (Steph.) R.M. Schust. &...     590071
# 1                     Calycularia laxa Lindb. & Arnell     588423
# 2                   Mannia levigata Shimizu & S. Hatt.      63065
# 3                 Asterella leptophylla (Mont.) Grolle      62971
# 4                 Asterella leptophylla (Mont.) Grolle      62971
# 5    Reboulia hemisphaerica subsp. australis R.M. S...     590126
# 6    Clevea nana (Shimizu & S. Hatt.) Borovich. & B...     590009
# 7               Conocephalum japonicum (Thunb.) Grolle     184206
# 8    Conocephalum salebrosum Szweyk., Buczk. & Odrzyk.     588480
# 9    Conocephalum salebrosum Szweyk., Buczk. & Odrzyk.     588480
# 10                         Marchantia paleacea Bertol.     350001
# 11             Mannia fragrans (Balb.) Frye & L. Clark      63061
# 12   Apotreubia nana (S. Hatt. & Inoue) S. Hatt. & ...     573460
# 13                      Ricciocarpos natans (L.) Corda     498049
# 14                                  Riccia fluitans L.     497877
# 15                      Preissia quadrata (Scop.) Nees     350040
# 16   Conocephalum salebrosum Szweyk., Buczk. & Odrzyk.     588480
# 17                     Metzgeria consanguinea Schiffn.     589938
# 26         Approved  2017-06-13
# 27         Approved  2017-06-13
# 28         Approved  2017-06-13
# 29         Approved  2017-06-13
# ..              ...         ...
# 97         Approved  2017-06-13
# 98         Approved  2017-06-13
# 99         Approved  2017-06-13
# 100  From plantlist  2017-06-13
# 101        Approved  2017-06-26
# 102        Approved  2017-06-13
# 103        Approved  2017-06-13
# 104        Approved  2017-06-13
# 105        Approved  2017-06-13
# 106        Approved  2017-06-13
# 107        Approved  2017-06-13
# 108        Approved  2017-06-26
# 109        Approved  2017-06-13
# 110        Approved  2017-06-13
# 111        Approved  2017-06-13
# 112        Approved  2017-06-13
# 113        Approved  2017-06-13
# 114        Approved  2017-06-13
# 115        Approved  2017-06-13
# 116        Approved  2017-06-21
# 117        Approved  2017-06-13
# 118        Approved  2017-06-13
# 119        Approved  2017-06-13
# 120  From plantlist  2017-06-13
# 121        Approved  2017-06-13
# 122        Approved  2017-06-13
# 123        Approved  2017-06-13
# 124        Approved  2017-06-13
# 125        Approved  2017-06-13
# 126  From plantlist  2017-06-13
#
# [127 rows x 35 columns]

# %% [markdown]
# #### DataFrames are convenient containers allowing to do complicated data filtering

# %% [markdown]
# Let's filter our dataset to records that have altitude defined (i.e. non-empty altitude parameter):

# %%
altitude_only = search_df[search_df.altitude != ''].copy()

# %%
altitude_only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 127 entries, 0 to 126
# Data columns (total 35 columns):
# acronym                    127 non-null object
# additionals                127 non-null object
# altitude                   127 non-null object
# branch                     127 non-null object
# collection_finished        127 non-null object
# collection_started         127 non-null object
# collectors                 127 non-null object
# country                    127 non-null object
# country_id                 127 non-null int64
# created                    127 non-null object
# details                    127 non-null object
# dethistory                 127 non-null object
# devstage                   127 non-null object
# district                   127 non-null object
# family                     127 non-null object
# family_authorship          127 non-null object
# fieldid                    127 non-null object
# genus                      127 non-null object
# genus_authorship           127 non-null object
# gpsbased                   127 non-null bool
# id                         127 non-null int64
# identification_finished    127 non-null object
# identification_started     127 non-null object
# identifiers                127 non-null object
# itemcode                   127 non-null object
# latitude                   127 non-null float64
# longitude                  127 non-null float64
# note                       127 non-null object
# region                     127 non-null object
# species_authorship         127 non-null object
# species_epithet            127 non-null object
# species_fullname           127 non-null object
# species_id                 127 non-null int64
# species_status             127 non-null object
# updated                    127 non-null object
# dtypes: bool(1), float64(2), int64(3), object(29)
# memory usage: 34.9+ KB

# %%
print('Average altitude is {} meters above sea level'.format(altitude_only.altitude.apply(pd.to_numeric, args=('coerce',)).mean()))
# Out:
# Average altitude is 665.0967741935484 meters above sea level

# %% [markdown]
# As you can see from the `.info()` output, `altitude` has the type `non-null object`, that means that its value could be quite arbitrary, e.g. a string, an array etc. We used `.astype` method to force its type to numeric, exactly, floating point. This is important in order to use the `.mean()` method.
# `Altitude` is a string that could have one of the forms: "700-900", "100", "300 m a.s.l." etc. So, one can wish to handle all of these cases smarty. To do so, [regular expressions](https://docs.python.org/3/library/re.html) could be used. Regular expressions are convenient tool to do numbers extraction.

# %% [markdown]
# Lets consider another filtering conditions: we will find all records collected at altitudes greater 1 km after 1 Aug, 2016.
#
# To start working with dates in Pandas we need to `datetime` objects.

# %%
altitude_only.altitude = altitude_only.altitude.apply(pd.to_numeric, args=('coerce',))
altitude_only.collection_started = pd.to_datetime(altitude_only.collection_started)

# %%
deadline = pd.to_datetime('2016-08-01')

# %%
altitude_only[(altitude_only.altitude > 1000) & (altitude_only.collection_started>deadline)]
# Out:
#     acronym                                        additionals  altitude  \
# 12     VBGI  [{'family_authorship': '', 'genus_authorship':...    1570.0
# 18     VBGI                                                 []    1570.0
# 31     VBGI  [{'family_authorship': '', 'genus_authorship':...    1640.0
# 36     VBGI                                                 []    1640.0
# 42     VBGI  [{'family_authorship': '', 'genus_authorship':...    1780.0
# 50     VBGI                                                 []    1370.0
# 54     VBGI  [{'family_authorship': '', 'genus_authorship':...    1640.0
# 93     VBGI  [{'family_authorship': '', 'genus_authorship':...    1460.0
# 124    VBGI  [{'family_authorship': '', 'genus_authorship':...    1570.0
#
#                   branch collection_finished collection_started    collectors  \
# 12   Bryophyte herbarium                             2016-08-04  V.A. Bakalin
# 18   Bryophyte herbarium                             2016-08-04  V.A. Bakalin
# 31   Bryophyte herbarium                             2016-08-06  V.A. Bakalin
# 36   Bryophyte herbarium                             2016-08-06  V.A. Bakalin
# 42   Bryophyte herbarium                             2016-08-08  V.A. Bakalin
# 50   Bryophyte herbarium                             2016-08-08  V.A. Bakalin
# 54   Bryophyte herbarium                             2016-08-09  V.A. Bakalin
# 93   Bryophyte herbarium                             2016-08-02  V.A. Bakalin
# 124  Bryophyte herbarium                             2016-08-04  V.A. Bakalin
#
#     country  country_id     created     ...       latitude   longitude  \
# 12   Russia         162  2017-04-07     ...      50.308056  134.664444
# 18   Russia         162  2017-04-07     ...      50.308056  134.664444
# 31   Russia         162  2017-04-07     ...      50.345556  134.661667
# 36   Russia         162  2017-04-07     ...      50.345556  134.661667
# 42   Russia         162  2017-04-07     ...      50.347222  134.643056
# 50   Russia         162  2017-04-07     ...      50.355556  134.635000
# 54   Russia         162  2017-04-07     ...      50.345556  134.661667
# 93   Russia         162  2017-04-07     ...      50.303056  134.670556
# 124  Russia         162  2017-04-07     ...      50.308056  134.664444
#
#                                                   note  \
# 12   Baidzhalsky Mountain System, Yarap River Middl...
# 18   Baidzhalsky Mountain System, Yarap River Middl...
# 31   Baidzhalsky Mountain System, Yarap River Middl...
# 36   Baidzhalsky Mountain System, Yarap River Middl...
# 42   Baidzhalsky Mountain System, Yarap River Middl...
# 50   Baidzhalsky Mountain System, Yarap River Middl...
# 54   Baidzhalsky Mountain System, Yarap River Middl...
# 93   Baidzhalsky Mountain System, Yarap River Middl...
# 124  Baidzhalsky Mountain System, Yarap River Middl...
#
#                               region                    species_authorship  \
# 12   Дальний Восток|Russian Far East  (S. Hatt. & Inoue) S. Hatt. & Mizut.
# 18   Дальний Восток|Russian Far East                       Lindb. & Arnell
# 31   Дальний Восток|Russian Far East                       Lindb. & Arnell
# 36   Дальний Восток|Russian Far East  (S. Hatt. & Inoue) S. Hatt. & Mizut.
# 42   Дальний Восток|Russian Far East                       Lindb. & Arnell
# 50   Дальний Восток|Russian Far East                     (Gottsche) Limpr.
# 54   Дальний Восток|Russian Far East                      (Schrank) Kuwah.
# 93   Дальний Восток|Russian Far East  (S. Hatt. & Inoue) S. Hatt. & Mizut.
# 124  Дальний Восток|Russian Far East                       Lindb. & Arnell
#
#     species_epithet                                   species_fullname  \
# 12             nana  Apotreubia nana (S. Hatt. & Inoue) S. Hatt. & ...
# 18             laxa                   Calycularia laxa Lindb. & Arnell
# 31             laxa                   Calycularia laxa Lindb. & Arnell
# 36             nana  Apotreubia nana (S. Hatt. & Inoue) S. Hatt. & ...
# 42             laxa                   Calycularia laxa Lindb. & Arnell
# 50         neesiana                  Pellia neesiana (Gottsche) Limpr.
# 54        pubescens            Apometzgeria pubescens (Schrank) Kuwah.
# 93             nana  Apotreubia nana (S. Hatt. & Inoue) S. Hatt. & ...
# 124            laxa                   Calycularia laxa Lindb. & Arnell
#
#     species_id  species_status     updated
# 12      573460  From plantlist  2017-06-13
# 18      588423        Approved  2017-06-13
# 31      588423        Approved  2017-06-13
# 36      573460  From plantlist  2017-06-13
# 42      588423        Approved  2017-06-13
# 50      425171        Approved  2017-06-13
# 54      363552        Approved  2017-06-19
# 93      573460  From plantlist  2017-06-13
# 124     588423        Approved  2017-06-13
#
# [9 rows x 35 columns]

# %% [markdown]
# ### Complex queries

# %% [markdown]
# Current version of the HTTP API (см. [HTTP-API Ddescription](https://github.com/VBGI/herbs/blob/master/herbs/docs/httpapi/ru/http_api.rst)) doesn't support quieries of OR-type. One cann't build a single query url that performs, for example, searching all the records with dates of collection either in Spring or Fall (but not Summer).
#
# Such type of quieries could be reached by `Pandas` with two or more consequent quieries to the database that could emulate OR-type quiery. Rising problem with a big data in this case doesn't matter because it is unlikely for the Herbarium database to be very large.
#
# Lets illustrate dividing an OR-type quiery into two regular quieries.
# We will consider two regular quieries named  `search_query1` and `search_query2`, and aims on building a complex one (i.e. `search_query1` OR `search_query2`):

# %%
search_query1 = (('collectedby', 'Крестов'),
                 ('identifiedby', 'Крестов') 
                 )
search_query2 = (('collectedby', 'Баркалов'),
                 ('identifiedby', 'Пименова')
                 )

# %%
from functools import reduce # `reduce` was moved into `functools` in Python3, so we need to import it 

# Make search queries consequently...
datastore = [] # storage for DataFrames corresponding to quieries
for sp in [search_query1, search_query2]:  # We have the only two quieries 
    # building searching url for each query
    search_request_url = HERBARIUM_SEARCH_URL + '?' + '&'.join(map(lambda x: x[0] + '=' + quote(x[1].strip()), sp))
    server_response = urlopen(search_request_url)
    data = json.loads(server_response.read().decode('utf-8'))
    data = pd.DataFrame(data['data'])
    datastore.append(data)  # storing results for each query
    server_response.close()  # close connection to the server

# Combine results using Pandas (combining is based on uniqueness of ID):
df_combined = pd.concat(datastore).drop_duplicates('id').reset_index()

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Data columns (total 36 columns):
# index                      519 non-null int64
# acronym                    519 non-null object
# additionals                519 non-null object
# altitude                   519 non-null object
# branch                     519 non-null object
# collection_finished        519 non-null object
# collection_started         519 non-null object
# collectors                 519 non-null object
# country                    519 non-null object
# country_id                 517 non-null float64
# created                    519 non-null object
# details                    519 non-null object
# dethistory                 519 non-null object
# devstage                   519 non-null object
# district                   519 non-null object
# family                     519 non-null object
# family_authorship          519 non-null object
# fieldid                    519 non-null object
# genus                      519 non-null object
# genus_authorship           519 non-null object
# gpsbased                   519 non-null bool
# id                         519 non-null int64
# identification_finished    519 non-null object
# identification_started     519 non-null object
# identifiers                519 non-null object
# itemcode                   519 non-null object
# latitude                   519 non-null float64
# longitude                  519 non-null float64
# note                       519 non-null object
# region                     519 non-null object
# species_authorship         519 non-null object
# species_epithet            519 non-null object
# species_fullname           519 non-null object
# species_id                 519 non-null int64
# species_status             519 non-null object
# updated                    519 non-null object
# dtypes: bool(1), float64(3), int64(3), object(29)
# memory usage: 142.5+ KB

# %%
df_combined.shape
# Out:
# (519, 36)

# %% [markdown]
# Original dimensions of composed DataFrame's:

# %%
datastore[0].shape, datastore[1].shape
# Out:
# ((175, 35), (346, 35))

# %% [markdown]
# ## Searching within Polygonal Areas

# %% [markdown]
# HTTP-API provides you ability to make rectangular-type geographic quieries, i.e. searching herbarium records
# included in specified areas. Internal database structure doesn't allow to make more general polygonal-type queries,
# but they could be emulated by means of `Python` and its third party packages.

# %% [markdown]
# Let us consider a problem of comparison plant diversity collected from Sakhalin Island and 200-km circle around of Petropavlovsk-Kamchatsky city.
# One of the ways to handle the problem is to use ESRI shapefile to restrict searching results by specified area.
# We will need `pyshp` and `shapely` packages to get reading shapefiles and evaluating spatially distributed data.
#
# So, if they aren't yet installed in your computational environment, install them with the `pip` tool or another Python package manager.

# %% [markdown]
# Also, we will suppose that ESRI shapefiles are stored in `shapefiles` folder existing in your current directory.
#
# In this case, basic reading workflow with shapefiles will be the following:

# %%
import shapefile
import numpy as np # Note: numpy is a part of Pandas pack: you can access numpy via pandas.np or pd.np

sakhalin_shp = shapefile.Reader("shapefiles/sakhalin.shp")

# %% [markdown]
# If no errors were occurred, one can plot loaded data:

# %%
contour_sakhalin = np.array(sakhalin_shp.shapes()[0].points)  #convert contour points to numpy array

# %% [markdown]
# ... and plotting:

# %%
from pylab import *
plot(contour_sakhalin[:,0], contour_sakhalin[:,1])
gca().set_aspect('equal')
title('Sakhalin Island')
show()

# %% [markdown]
# The contour of the shapefile -- a coastline -- consist of 835 points.

# %%
contour_sakhalin.shape
# Out:
# (835, 2)

# %% [markdown]
# Bounding box of the shapefile is easily accessable from shapefile specification

# %%
sakhalin_shp.bbox
# Out:
# [141.63803100585938, 45.88860321044922, 144.75164794921875, 54.424713134765625]

# %% [markdown]
# Lets build a search url, according to previous steps:

# %%
query_sakhalin_bbox = tuple(zip(['lonl', 'latl', 'lonu', 'latu'], map(str, sakhalin_shp.bbox)))
print(query_sakhalin_bbox)
# Out:
# (('lonl', '141.63803100585938'), ('latl', '45.88860321044922'), ('lonu', '144.75164794921875'), ('latu', '54.424713134765625'))

# %%
within_sakhalin_request_url = HERBARIUM_SEARCH_URL + '?' + '&'.join(map(lambda x: x[0] + '=' + quote(x[1].strip()), query_sakhalin_bbox))

# %%
within_sakhalin_request_url  #it is good to inspect an url before sending a request
# Out:
# 'http://botsad.ru/hitem/json/?lonl=141.63803100585938&latl=45.88860321044922&lonu=144.75164794921875&latu=54.424713134765625'

# %% [markdown]
# Getting data within Sakhalin Island bounding box:

# %%
server_response = urlopen(within_sakhalin_request_url)
sakhalin_data_in_bbox = pd.DataFrame(json.loads(server_response.read().decode('utf-8'))['data'])

# %% [markdown]
# Next step assumes applying a fine filtering with help of the `Polygon` class instance:

# %%
from shapely.geometry import Polygon, Point
closed_sakhalin_contour = np.vstack([contour_sakhalin, contour_sakhalin[-1]]) # Polygon should be closed to check inclusions
sakhalin_poly = Polygon(closed_sakhalin_contour)

# %%
sakhalin_filtered = sakhalin_data_in_bbox[[sakhalin_poly.contains(Point(x,y)) for x,y in zip(sakhalin_data_in_bbox.longitude, sakhalin_data_in_bbox.latitude)]]

# %%
sakhalin_filtered
# Out:
#     acronym                                        additionals altitude  \
# 0      VBGI                                                 []
# 1      VBGI                                                 []
# 2      VBGI                                                 []
# 3      VBGI                                                 []
# 4      VBGI                                                 []
# 5      VBGI                                                 []
# 6      VBGI                                                 []
# 7      VBGI  [{'family_authorship': '', 'genus_authorship':...      268
# 8      VBGI  [{'family_authorship': '', 'genus_authorship':...      268
# 9      VBGI  [{'family_authorship': '', 'genus_authorship':...      268
# 10     VBGI  [{'family_authorship': '', 'genus_authorship':...      268
# 11     VBGI  [{'family_authorship': '', 'genus_authorship':...      268
# 12     VBGI  [{'family_authorship': '', 'genus_authorship':...      268
# 13     VBGI  [{'family_authorship': '', 'genus_authorship':...      268
# 14     VBGI                                                 []      268
# 15     VBGI                                                 []
# 16     VBGI                                                 []
# 17     VBGI                                                 []
# 18     VBGI                                                 []
# 19     VBGI                                                 []
# 20     VBGI                                                 []      900
# 21     VBGI                                                 []
# 22     VBGI                                                 []      600
# 23     VBGI  [{'family_authorship': '', 'genus_authorship':...      268
# 24     VBGI                                                 []      268
# 25     VBGI  [{'family_authorship': '', 'genus_authorship':...      268
# 26     VBGI                                                 []
# 27     VBGI                                                 []
# 28     VBGI                                                 []
# 29     VBGI                                                 []
# ..      ...                                                ...      ...
# 171    VBGI                                                 []       60
# 172    VBGI                                                 []       60
# 173    VBGI                                                 []       70
# 174    VBGI                                                 []       70
# 175    VBGI                                                 []       70
# 176    VBGI                                                 []      170
# 177    VBGI                                                 []      120
# 178    VBGI                                                 []      160
# 180    VBGI                                                 []       50
# 181    VBGI                                                 []      380
# 182    VBGI                                                 []       40
# 183    VBGI                                                 []       40
# 184    VBGI                                                 []       40
# 185    VBGI                                                 []       70
# 186    VBGI                                                 []      140
# 187    VBGI                                                 []       15
# 188    VBGI                                                 []      250
# 189    VBGI                                                 []      250
# 190    VBGI                                                 []      792
# 191    VBGI                                                 []     1042
# 192    VBGI                                                 []      792
# 193    VBGI                                                 []     1042
# 194    VBGI                                                 []     1042
# 195    VBGI                                                 []     1042
# 196    VBGI                                                 []      792
# 197    VBGI                                                 []     1042
# 198    VBGI                                                 []      192
# 199    VBGI                                                 []      192
# 16      ...      46.953190  142.735855
# 17      ...      46.964113  142.734756
# 18      ...      46.964113  142.734756
# 19      ...      47.053937  142.726656
# 20      ...      49.874000  143.483000
# 21      ...      48.627222  142.778243
# 22      ...      49.873000  143.477000
# 23      ...      47.080000  142.580000
# 24      ...      47.079000  142.580000
# 25      ...      47.079000  142.580000
# 26      ...      46.903154  142.749958
# 27      ...      46.911129  142.620868
# 28      ...      46.911129  142.620868
# 29      ...      46.911129  142.620868
# ..      ...            ...         ...
# 171     ...      46.591812  141.853666
# 172     ...      46.591812  141.853666
# 173     ...      47.123527  142.078541
# 174     ...      47.123527  142.078541
# 175     ...      47.123527  142.078541
# 176     ...      46.971610  142.771834
# 177     ...      46.601238  141.872738
# 178     ...      46.899450  142.822839
# 180     ...      50.590920  143.653579
# 181     ...      46.997114  142.813640
# 182     ...      46.585412  141.871262
# 183     ...      46.585412  141.871262
# 184     ...      46.585412  141.871262
# 185     ...      50.611676  143.693962
# 186     ...      46.987747  142.779093
# 187     ...      50.625291  143.691902
# 188     ...      47.074681  142.593626
# 189     ...      47.074681  142.593626
# 190     ...      46.987425  142.830981
# 191     ...      47.005332  142.840491
# 192     ...      46.987425  142.830981
# 193     ...      47.005332  142.840491
# 194     ...      47.005332  142.840491
# 195     ...      47.005332  142.840491
# 196     ...      46.987425  142.830981
# 197     ...      47.005332  142.840491
# 198     ...      47.075517  142.614182
# 199     ...      47.075517  142.614182
# 200     ...      47.287820  141.983075
# 201     ...      47.287820  141.983075
#
#                                                   note  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7    Southern part of Sakhalin Island. Yuzhno-SAkha...
# 8    Southern part of Sakhalin Island. Yuzhno-Sakha...
# 9    Southern part of SAkhalin Island. Yuzhno-Sakha...
# 10   Southern part of Sakhalin Island. Yuzhno-Sakha...
# 11   Soutern part of Sakhalin Isl.  Yuzhno-SAkhalin...
# 12   Southern part of Sakhalin Island. Yuzhno-SAkha...
# 13   Southern part of Sakhalin Island. Yuzhno-Sakha...
# 14   Suther part of SAkhalin Island. Yuzhno-SAkhali...
# 15
# 16
# 17
# 18
# 19
# 20   Остров Сахалин. Восточно-Сахалинские горы, Цен...
# 21
# 22   Central part of Sakhalin Island. Vostochno-Sac...
# 23   Southern part of Sakhalin Island. Yuzhno-Sakha...
# 24   Southern part of Sakhalin Island. Yuzhno-SAkha...
# 25   Southern part of Sakhalin Island. Yuzhno-Sakha...
# 26
# 27
# 28
# 29
# ..                                                 ...
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188                           одиночное крупное дерево
# 189                           одиночное крупное дерево
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
#
#                                     region                species_authorship  \
# 0    Сахалинская область / Sakhalin Oblast   (C. Presl) Fraser-Jenk. & Jermy
# 1    Сахалинская область / Sakhalin Oblast   (C. Presl) Fraser-Jenk. & Jermy
# 2    Сахалинская область / Sakhalin Oblast   (C. Presl) Fraser-Jenk. & Jermy
# 3    Сахалинская область / Sakhalin Oblast   (C. Presl) Fraser-Jenk. & Jermy
# 4    Сахалинская область / Sakhalin Oblast  (Jacq.) Woyn. ex Schinz & Thell.
# 5    Сахалинская область / Sakhalin Oblast  (Jacq.) Woyn. ex Schinz & Thell.
# 200                       Сахалинская обл.                             Blume
# 201                       Сахалинская обл.                             Blume
#
#      species_epithet                                   species_fullname  \
# 0            expansa  Dryopteris expansa (C. Presl) Fraser-Jenk. & J...
# 1            expansa  Dryopteris expansa (C. Presl) Fraser-Jenk. & J...
# 2            expansa  Dryopteris expansa (C. Presl) Fraser-Jenk. & J...
# 3            expansa  Dryopteris expansa (C. Presl) Fraser-Jenk. & J...
# 4          austriaca  Dryopteris austriaca (Jacq.) Woyn. ex Schinz &...
# 5          austriaca  Dryopteris austriaca (Jacq.) Woyn. ex Schinz &...
# 6            expansa  Dryopteris expansa (C. Presl) Fraser-Jenk. & J...
# 7          latifrons                Riccardia latifrons (Lindb.) Lindb.
# 8          latifrons                Riccardia latifrons (Lindb.) Lindb.
# 9         aeruginosa                        Riccardia aeruginosa Furuki
# 10        aeruginosa                        Riccardia aeruginosa Furuki
# 11     chamedryfolia             Riccardia chamedryfolia (With.) Grolle
# 12     chamedryfolia             Riccardia chamedryfolia (With.) Grolle
# 13     chamedryfolia             Riccardia chamedryfolia (With.) Grolle
# 14     chamedryfolia             Riccardia chamedryfolia (With.) Grolle
# 15         amurensis                     Leptorumohra amurensis Tzvelev
# 16         amurensis                     Leptorumohra amurensis Tzvelev
# 17         amurensis                     Leptorumohra amurensis Tzvelev
# 18         amurensis                     Leptorumohra amurensis Tzvelev
# 19         amurensis                     Leptorumohra amurensis Tzvelev
# 20         pubescens            Apometzgeria pubescens (Schrank) Kuwah.
# 21          fragilis                   Cystopteris fragilis (L.) Bernh.
# 22          japonica    Sauteria japonica (Shimizu & S. Hatt.) S. Hatt.
# 23        salebrosum  Conocephalum salebrosum Szweyk., Buczk. & Odrzyk.
# 24           conicum                  Conocephalum conicum (L.) Underw.
# 25         japonicum             Conocephalum japonicum (Thunb.) Grolle
# 26   heterotropoides                   Asarum heterotropoides F.Schmidt
# 27   heterotropoides                   Asarum heterotropoides F.Schmidt
# 28   heterotropoides                   Asarum heterotropoides F.Schmidt
# 29   heterotropoides                   Asarum heterotropoides F.Schmidt
# ..               ...                                                ...
# 171     sachalinense      Phellodendron sachalinense (F. Schmidt) Sarg.
# 172     sachalinense      Phellodendron sachalinense (F. Schmidt) Sarg.
# 173           repens                               Skimmia repens Nakai
# 174           repens                               Skimmia repens Nakai
# 175           repens                               Skimmia repens Nakai
# 176         odoratum                         Galium odoratum (L.) Scop.
# 177       macroptera                          Euonymus macroptera Rupr.
# 178    sachalinensis          Euonymus sachalinensis (F.Schmidt) Maxim.
# 180         fragrans                    Dryopteris fragrans (L.) Schott
# 181        tripteron             Polystichum tripteron (Kunze) C. Presl
# 182          fauriei                          Cardamine fauriei H. Lév.
# 183          fauriei                          Cardamine fauriei H. Lév.
# 184          fauriei                          Cardamine fauriei H. Lév.
# 185    amplexifolius                  Streptopus amplexifolius (L.) DC.
# 186         cordatum              Cardiocrinum cordatum (Thunb.) Makino
# 187   camschatcensis          Fritillaria camschatcensis (L.) Ker Gawl.
# 188            regia                                   Juglans regia L.
# 189            regia                                   Juglans regia L.
# (202, 35)

# %% [markdown]
# Now, we will find ID's of points belonging to bounding box of Sakhalin Island, but not to its countour (coastline)  defined in the shapefile.

# %%
set(sakhalin_data_in_bbox.id.values) - set(sakhalin_filtered.id.values)
# Out:
# {1403,
#  1412,
#  1432,
#  1434,
#  1438,
#  1439,
#  1529,
#  10015,
#  10016,
#  10373,
#  19820,
#  19823,
#  19912,
#  20830,
#  20832}

# %% [markdown]
# Inspecting positions of the filtered points, e.g. ID=1412 (see http://botsad.ru/hitem/1412), one can conclude
# that all filtered records were collected near the coastline; this is probably caused by errors in herbarium records and coastline points positioning.So, that isn't a true error, but such cases should be taken in mind when do filtering by polygonal areas.

# %% [markdown]
# Lets find herbarium records collected in the proximity of Petropavlovsk-Kamchatsky city.
# Firstly, we will set coordinates of Petropavlovsk-Kamchatsky and define a bounding box that includes 200-km circle around this point:

# %%
kamchatka_bbox = [151.1, 47.8, 172.0, 58.3]
petropavlovsk_coords = (53.145992, 158.683548)

# %% [markdown]
# The Earth shape isn't a prefect sphere, so we will need an additional tool that provides a function to get estimation of distances between geographically distributed points.
# `Geopy` package provides necessary functionality to do distance computation.

# %%
from geopy.distance import vincenty
query_kamchatka_bbox = tuple(zip(['lonl', 'latl', 'lonu', 'latu'], map(str, kamchatka_bbox)))
near_petropavlovsk_kamchatsky_url = HERBARIUM_SEARCH_URL + '?' + '&'.join(map(lambda x: x[0] + '=' + quote(x[1].strip()), query_kamchatka_bbox))
server_response = urlopen(near_petropavlovsk_kamchatsky_url)
petropavlovsk_data_in_bbox = pd.DataFrame(json.loads(server_response.read().decode('utf-8'))['data'])
petropavlovsk_data_in_bbox.shape
# Out:
# (144, 35)

# %%
petropavlovsk_filtered = petropavlovsk_data_in_bbox[[vincenty((lat, lon), petropavlovsk_coords).km < 200.0 for lat,lon in zip(petropavlovsk_data_in_bbox.latitude, petropavlovsk_data_in_bbox.longitude)]]

# %%
petropavlovsk_filtered.shape
# Out:
# (59, 35)

# %% [markdown]
# When the datasets are obtained, we can carry out some investigaions (e.g. comparison analysis):

# %%
print('The number of unique genera in 200 km circle around the Petropavlovsk-Kamchatsky city:', len(petropavlovsk_filtered.genus.unique()))
# Out:
# The number of unique genera in 200 km circle around the Petropavlovsk-Kamchatsky city: 16

# %%
print('The number of unique species in 200-km circle around the Petropavlovsk-Kamchatsky city:', len(petropavlovsk_filtered.species_id.unique()))
# Out:
# The number of unique species in 200-km circle around the Petropavlovsk-Kamchatsky city: 18

# %%
print('The number of unique genera at Sakhalin Island:', len(sakhalin_filtered.species_id.unique()))
# Out:
# The number of unique genera at Sakhalin Island: 90

# %%
print('The number of unique species at Sakhalin Island:', len(sakhalin_filtered.genus.unique()))
# Out:
# The number of unique species at Sakhalin Island: 71

# %% [markdown]
# Lets count frequences:

# %%
from collections import Counter

# %% [markdown]
# Genera frequences near the Petropavlovsk-Kamchatsky city

# %%
petropavlovsk_freq = petropavlovsk_filtered.genus.value_counts() / len(petropavlovsk_filtered)
petropavlovsk_freq
# Out:
# Aneura          0.152542
# Moerckia        0.118644
# Riccardia       0.118644
# Peltolepis      0.101695
# Conocephalum    0.084746
# Calycularia     0.067797
# Sauteria        0.050847
# Preissia        0.050847
# Marchantia      0.050847
# Pellia          0.050847
# Blasia          0.033898
# Polystichum     0.033898
# Athyrium        0.033898
# Nardia          0.016949
# Mannia          0.016949
# Cystopteris     0.016949
# Name: genus, dtype: float64

# %% [markdown]
# Genera frequences at Sakhalin Island:

# %%
sakhalin_freq = sakhalin_filtered.genus.value_counts() / len(sakhalin_filtered)
sakhalin_freq
# Out:
# Riccardia        0.101604
# Conocephalum     0.096257
# Asarum           0.064171
# Dryopteris       0.042781
# Marchantia       0.037433
# Sauteria         0.032086
# Woodsia          0.032086
# Peltolepis       0.026738
# Asterella        0.026738
# Leptorumohra     0.026738
# Reboulia         0.026738
# Cacalia          0.021390
# Prunus           0.021390
# Phellodendron    0.016043
# Euonymus         0.016043
# Gentiana         0.016043
# Cardamine        0.016043
# Cypripedium      0.016043
# Skimmia          0.016043
# Blasia           0.010695
# Cortusa          0.010695
# Betula           0.010695
# Juglans          0.010695
# Quercus          0.010695
# Metzgeria        0.010695
# Apometzgeria     0.010695
# Vaccinium        0.010695
# Lupinus          0.010695
# Actinidia        0.010695
# Aneura           0.010695
#                    ...
# Androsace        0.005348
# Streptopus       0.005348
# Malva            0.005348
# Plagiochasma     0.005348
# Hippophae        0.005348
# Ribes            0.005348
# Calycularia      0.005348
# Astragalus       0.005348
# Trautvetteria    0.005348
# Cryptotaenia     0.005348
# Polystichum      0.005348
# Artemisia        0.005348
# Hierochloe       0.005348
# Hydrangea        0.005348
# Beckmannia       0.005348
# Fritillaria      0.005348
# Geranium         0.005348
# Matteuccia       0.005348
# Cardiocrinum     0.005348
# Corydalis        0.005348
# Ilex             0.005348
# Primula          0.005348
# Rubus            0.005348
# Brylkinia        0.005348
# Larix            0.005348
# Arisaema         0.005348
# Potentilla       0.005348
# Spiraea          0.005348
# Galium           0.005348
# Vitis            0.005348
# Name: genus, dtype: float64

# %% [markdown]
# Shannon's informational measures:

# %%
shannon_sakhalin = - sum(np.log2(sakhalin_freq.values) * sakhalin_freq.values)
shannon_sakhalin
# Out:
# 5.4590455606158228

# %%
shannon_petropavlovsk = - sum(np.log2(petropavlovsk_freq.values) * petropavlovsk_freq.values)
shannon_petropavlovsk
# Out:
# 3.7136386525956571

# %% [markdown]
# Relative values of informational measures (relative to its theoretically maximal value):

# %%
shannon_sakhalin_relative = shannon_sakhalin / np.log2(len(sakhalin_freq))
shannon_sakhalin_relative
# Out:
# 0.88768618522569587

# %%
shannon_petropavlovsk_relative = shannon_petropavlovsk / np.log2(len(petropavlovsk_freq))
shannon_petropavlovsk_relative
# Out:
# 0.92840966314891427

# %% [markdown]
# **Note:** One can be confused looking at the results: genus diversity near the Petropavlovsk-Kamchatsky city is greater than in Sakhalin Island; this could be caused by lots of impacts -- such as Herbarium database filling pecularities (the database filling is still in progress...) and just by a statistical ambiguity; records in the database are collected and filled out in a non-random and/or non-regular way that, in turn, may lead to fake conclusions. So, be careful making any conclusions...
