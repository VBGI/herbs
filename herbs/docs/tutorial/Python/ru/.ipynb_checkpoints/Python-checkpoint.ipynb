# %% [markdown]
# # Автоматизация поиска на Python

# %% [markdown]
# Язык программирования Python все больше находит свое применение в инженерных и научных расчетах рачётах, а также в анализе данных.
#
# Среди причин популярности языка является его лаконичность и удобство чтения кода, который, учитывая синтаксис языка, а также рекомендации по написанию кода pep8, просто не может выглядеть плохо читаемым.

# %% [markdown]
# ## Простые запросы

# %% [markdown]
# Импортируем пакет Pandas. Данный пакет содержит большое количество полезных функций для выполнения операций загрузки и предварительной обработки данных, имеющих различную структуру.

# %%
import pandas as pd

# %% [markdown]
# Определим глобальную переменную `HERBARIUM_SEARCH_URL`, которая будет указывать на URL, по которому следует посылать поисковые запросы к электронному гербарному каталогу.

# %%
HERBARIUM_SEARCH_URL = 'http://botsad.ru/hitem/json/'

# %% [markdown]
# Формирование поисковых запросов допускается как по шифрованному HTTPS протоколу, так и без шифрования HTTP. В случае использования HTTPS, это следует указать в переменной `HERBARIUM_SEARCH_URL`, т.е. заменить "http://" на "https://".

# %% [markdown]
# Зададим поисковые параметры и их значения в виде списка:
# (полный перечень доступных поисковых параметров можно посмотреть по ссылке)

# %%
search_parameters = (('collectedby', 'Крестов'),
                     ('identifiedby', 'Крестов'),
                     ('colstart', '01.01.2016'),
                     ('colend', '30.12.2016')
                    )

# %% [markdown]
# Количество параметров, зада

# %% [markdown]
# Импортируем необходимые библиотеки для выполнения HTTP-запроса к серверу. В зависимости от используемой версии Python импортирование выполняется по разному. И хотя Python 2.x в скором будущем перестанет официально поддерживаться, ниже дается фрагмент кода подходящий как для Python 2.x, так и Python 3.x:

# %%
try:
    # Python 3.x
    from urllib.parse import quote
    from urllib.request import urlopen
except ImportError:
    # Python 2.x
    from urllib import quote
    from urllib import urlopen

# %% [markdown]
# Создадим текущий поисковый url, используя значения поисковых параметров `search_parameters`:

# %%
search_request_url = HERBARIUM_SEARCH_URL + '?' + '&'.join(map(lambda x: x[0] + '=' + quote(x[1].strip()), search_parameters))

# %% [markdown]
# Поскольку в соответствии со спецификацией URI не должен содержать не ASCII-символы, каковыми в частности являются буквы русского алфавита, участвующие в поисковом запросе, здесь используется вспомогательная функция `quote`, которая берет на себя операцию кодирования таких символов.
#
# В случе несложных запросов, поисковый URI можно записать одной строкой и не вводить вспомогательную структуру `search_parameters`. Однако, схема с использованием `search_parameters` более общая, позволяет структурировать поисковые запросы, создавав предварительно их массив, например:
#
# ```python
# list_of_search_pars = [search_parameters1, search_parameters1, search_parameters1,]
# ```

# %% [markdown]
# Вот так выглядит поисковый url (`search_request_url`).

# %%
search_request_url
# Out:
# 'http://botsad.ru/hitem/json/?collectedby=%D0%9A%D1%80%D0%B5%D1%81%D1%82%D0%BE%D0%B2&identifiedby=%D0%9A%D1%80%D0%B5%D1%81%D1%82%D0%BE%D0%B2&colstart=01.01.2016&colend=30.12.2016'

# %%
import json
server_response = urlopen(search_request_url)
data = json.loads(server_response.read().decode('utf-8'))
server_response.close()

# %% [markdown]
# Теперь переменная `data` представляeт собой Python-словарь с полями, определенными в документе, описывающим спецификацию json-ответа сервера на поисковый запрос.

# %% [markdown]
# Прежде чем начать работать с полученными данными, важно проверить, прошла ли загрузка данных без ошибок и предупреждений.
# Для этого следует посмотреть значения полей `errors` и `warnings` структуры `data`. В случае успешно выполненного запроса, поля должны быть пустыми.

# %%
data['errors'], data['warnings']
# Out:
# ([], [])

# %% [markdown]
# Следует отметить, что наличие предупреждений `warnings`, не является критичным; более того, при некоторых видах поисковых запросов, наличие `warnings` неизбежно; Таким образом, обработку данных следует продолжать и при не пустом значении поля `warnings`.
#
# Тем не менее, полностью игнорировать `warnings` не следует; данный параметр может содержать полезную информацию о результатах поиска и\или корректности поискового запроса.

# %% [markdown]
# Данный запрос был выполнен без ошибок и предупреждений (по крайней мере, по состоянию на 19 июня 2017 г), теперь можно работать с данными средствами Python, pandas и т.п.

# %%
print("Количество записей, удовлетворящих Вашему поисковому запросу равно:", len(data['data']))
# Out:
# Количество записей, удовлетворящих Вашему поисковому запросу равно: 173

# %% [markdown]
# Для большего удобстав работы с данными, рекомендуется преобразовать их в DataFrame-объект из пакета Pandas. Для этого, достаточно подать на вход конструктора DataFrame словарь `data['data']`:

# %%
search_df = pd.DataFrame(data['data'])

# %% [markdown]
# Общую информацию о созданном DataFrame-объекте можно получить используя методы `.info()` или `.describe()`:

# %%
search_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 35 columns):
# acronym                    173 non-null object
# additionals                173 non-null object
# altitude                   173 non-null object
# branch                     173 non-null object
# collection_finished        173 non-null object
# collection_started         173 non-null object
# collectors                 173 non-null object
# country                    173 non-null object
# country_id                 173 non-null int64
# created                    173 non-null object
# details                    173 non-null object
# dethistory                 173 non-null object
# devstage                   173 non-null object
# district                   173 non-null object
# family                     173 non-null object
# family_authorship          173 non-null object
# fieldid                    173 non-null object
# genus                      173 non-null object
# genus_authorship           173 non-null object
# gpsbased                   173 non-null bool
# id                         173 non-null int64
# identification_finished    173 non-null object
# identification_started     173 non-null object
# identifiers                173 non-null object
# itemcode                   173 non-null object
# latitude                   173 non-null float64
# longitude                  173 non-null float64
# note                       173 non-null object
# region                     173 non-null object
# species_authorship         173 non-null object
# species_epithet            173 non-null object
# species_fullname           173 non-null object
# species_id                 173 non-null int64
# species_status             173 non-null object
# updated                    173 non-null object
# dtypes: bool(1), float64(2), int64(3), object(29)
# memory usage: 46.2+ KB

# %% [markdown]
# Так выглядит сокращенный вариант таблицы гербарных данных:

# %%
search_df
# Out:
#     acronym additionals altitude branch collection_finished  \
# 0      VBGI          []
# 1      VBGI          []
# 2      VBGI          []
# 3      VBGI          []      700
# 4      VBGI          []      700
# 5      VBGI          []      700
# 6      VBGI          []      700
# 7      VBGI          []
# 8      VBGI          []     1300
# 9      VBGI          []
# 10     VBGI          []      600
# 11     VBGI          []      600
# 12     VBGI          []     1200
# 13     VBGI          []     1500
# 14     VBGI          []     1200
# 15     VBGI          []
# 16     VBGI          []
# 17     VBGI          []
# 18     VBGI          []     1500
# 19     VBGI          []     1500
# 20     VBGI          []
# 21     VBGI          []     1378
# 22     VBGI          []     1687                 2016-08-11
# 23     VBGI          []      551
# 24     VBGI          []
# 25     VBGI          []
# 26     VBGI          []      550
# 27     VBGI          []      550
# 28     VBGI          []
# 29     VBGI          []      551                 2016-08-10
# ..      ...         ...      ...    ...                 ...
# 143    VBGI          []                          2016-08-13
# 144    VBGI          []                          2016-08-13
# 145    VBGI          []
# 146    VBGI          []
# 147    VBGI          []
# 148    VBGI          []      543
# 149    VBGI          []     1200
# 150    VBGI          []     1200
# 151    VBGI          []     1200
# 152    VBGI          []     1000
# 153    VBGI          []     1200
# 154    VBGI          []      600
# 155    VBGI          []
# 156    VBGI          []
# 157    VBGI          []
# 158    VBGI          []
# 159    VBGI          []
# 160    VBGI          []
# 161    VBGI          []
# 162    VBGI          []
# 163    VBGI          []
# 164    VBGI          []
# 165    VBGI          []                          2016-08-13
# 166    VBGI          []                          2016-07-31
# 167    VBGI          []                          2016-07-30
# 168    VBGI          []                          2016-07-30
# 169    VBGI          []      551                 2016-08-10
# 170    VBGI          []     1000                 2016-08-11
# 171    VBGI          []     1687                 2016-08-11
# 172    VBGI          []     1687                 2016-08-11
#
#     collection_started                    collectors country  country_id  \
# 0           2016-08-10                  Крестов П.В.  Russia         162
# 1           2016-08-10                  Крестов П.В.  Russia         162
# 2           2016-08-10                  Крестов П.В.  Russia         162
# 3           2016-08-09                  Крестов П.В.  Russia         162
# 4           2016-08-09                  Крестов П.В.  Russia         162
# 5           2016-08-09                  Крестов П.В.  Russia         162
# 6           2016-08-09                  Крестов П.В.  Russia         162
# 7           2016-07-31                  Крестов П.В.  Russia         162
# 8           2016-07-30                  Крестов П.В.  Russia         162
# 9           2016-08-10                  Крестов П.В.  Russia         162
# 10          2016-08-13                  Крестов П.В.  Russia         162
# 11          2016-08-13                  Крестов П.В.  Russia         162
# 12          2016-07-30                  Крестов П.В.  Russia         162
# 13          2016-08-08                  Крестов П.В.  Russia         162
# 14          2016-07-30                  Крестов П.В.  Russia         162
# 15          2016-08-10                  Крестов П.В.  Russia         162
# 16          2016-08-10                  Крестов П.В.  Russia         162
# 17          2016-08-09                  Крестов П.В.  Russia         162
# 18          2016-08-02                  Крестов П.В.  Russia         162
# 19          2016-08-02                  Крестов П.В.  Russia         162
# 20          2016-07-31                  Крестов П.В.  Russia         162
# 21          2016-08-08                  Крестов П.В.  Russia         162
# 22          2016-08-11                  Крестов П.В.  Russia         162
# 23          2016-08-10                  Крестов П.В.  Russia         162
# 24          2016-08-10                  Крестов П.В.  Russia         162
# 25          2016-07-31                  Крестов П.В.  Russia         162
# 26          2016-07-31                  Крестов П.В.  Russia         162
# 27          2016-07-30                  Крестов П.В.  Russia         162
# 28          2016-08-02                  Крестов П.В.  Russia         162
# 29          2016-08-10                  Крестов П.В.  Russia         162
# ..                 ...                           ...     ...         ...
# 143         2016-08-13                  Крестов П.В.  Russia         162
# 144         2016-08-13                  Крестов П.В.  Russia         162
# 169         дерево высотой 14 м  Хабаровский край
# 170                              Хабаровский край
# 171                              Хабаровский край
# 172                              Хабаровский край
#
#                        species_authorship   species_epithet  \
# 0                       (Trevir.) Griseb.         latifolia
# 1                            A.P. Khokhr.          sudetica
# 2                            A.P. Khokhr.          sudetica
# 3                                 Tzvelev         amurensis
# 4                          (Maxim.) Ching         spinulosa
# 5                          (Maxim.) Ching         spinulosa
# 6                               (L.) Kuhn         aquilinum
# 7                             (L.) Schott          fragrans
# 8                          Regel & Tiling         ajanensis
# 9                                   Dewey          disperma
# 10                                     L.        sylvaticum
# 11                                     L.        sylvaticum
# 12                    Trautv. & C.A. Mey.      ukurunduense
# 13                         Regel & Tiling         ajanensis
# 14            (Fisch. ex Trevir.) Pimenov     terebinthacea
# 15           (F.Schmidt) Benth. ex Maxim.      maximowiczii
# 16           (F.Schmidt) Benth. ex Maxim.      maximowiczii
# 17                                   Miq.           keiskei
# 18                     Trautv. & C.A.Mey.     middendorffii
# 19                     Trautv. & C.A.Mey.     middendorffii
# 20                                M.Bieb.      verticillata
# 21   (Trautv. & C.A.Mey.) Takeda & Miyake      anticleoides
# 22          Willd. ex Schult. & Schult.f.         splendens
# 23                     Fisch. & C.A. Mey.          davurica
# 24                     Trautv. & C.A.Mey.          gigantea
# 25                                 Turcz.      schelichowii
# 26                          (Rupr.) Regel      maximowiczii
# 27                                     L.          racemosa
# 28                  (Gorodkov) V.I.Krecz.       rigidioides
# 29             (Trautv. ex Maxim.) Maxim.       nephrolepis
# ..                                    ...               ...
# 143                                  Lam.          punctata
# 144                                  Kom.       ussuriensis
# 145                            (L.) Fenzl       lateriflora
# 146                          (Maxim.) Pax         sylvatica
# 147                                 Nakai        neoserrata
# 148                                   Sw.        pallescens
# 149                   Trautv. & C.A. Mey.      ukurunduense
# 150                     (Kom.) L.H.Bailey            suavis
# 151           (Fisch. ex Trevir.) Pimenov     terebinthacea
# 152                (Fisch. ex Besser) DC.       lagocephala
# 153                        (Rupr.) Pouzar         fruticosa
# 154       (C. Presl) Fraser-Jenk. & Jermy           expansa
# 155                                    L.          dauricum
# 156                           (L.) Schott          fragrans
# 157          (Turcz. ex Kunze) Sa. Kurata         sibiricum
# 158                         (L.) H.Koyama          hastatus
# 159                             (L.) Opiz              alba
# 160                                Turcz.      schelichowii
# 161                                Maxim.  middendorffianum
# 162                      (Janch.) Pojark.       palczewskii
# 163                               M.Bieb.      verticillata
# 164                        Maxim. ex Kom.         savatieri
# 165  (Fisch. & C.A. Mey. ex Turcz.) Hiroë        seseloides
# 166                                    L.         compactum
# 167                         (Pall.) Regel            pumila
# 168                       Siebold & Zucc.        koraiensis
# 169            (Trautv. ex Maxim.) Maxim.       nephrolepis
# 170                            (L.) R.Br.            repens
# 171         Willd. ex Schult. & Schult.f.         splendens
# 172             (Franch. & Sav.) Jacobsen             rosea
#
#                                       species_fullname species_id  \
# 0                    Cinna latifolia (Trevir.) Griseb.     446416
# 1                Rhizomatopteris sudetica A.P. Khokhr.     204221
# 2                Rhizomatopteris sudetica A.P. Khokhr.     204221
# 3                       Leptorumohra amurensis Tzvelev     215409
# 4           Pseudocystopteris spinulosa (Maxim.) Ching     588188
# 5           Pseudocystopteris spinulosa (Maxim.) Ching     588188
# 6                        Pteridium aquilinum (L.) Kuhn     205696
# 7                      Dryopteris fragrans (L.) Schott     212858
# 8                    Tilingia ajanensis Regel & Tiling      34270
# 9                                 Carex disperma Dewey     198160
# 10                             Equisetum sylvaticum L.     219650
# 11                             Equisetum sylvaticum L.     219650
# 12               Acer ukurunduense Trautv. & C.A. Mey.     588172
# 13                   Tilingia ajanensis Regel & Tiling      34270
# 14   Kitagawia terebinthacea (Fisch. ex Trevir.) Pi...     588202
# 15   Angelica maximowiczii (F.Schmidt) Benth. ex Ma...      28096
# 16   Angelica maximowiczii (F.Schmidt) Benth. ex Ma...      28096
# 17                            Convallaria keiskei Miq.      56562
# 18       Hemerocallis middendorffii Trautv. & C.A.Mey.     585041
# 19       Hemerocallis middendorffii Trautv. & C.A.Mey.     585041
# 20                          Paris verticillata M.Bieb.     350346
# 21   Veratrum anticleoides (Trautv. & C.A.Mey.) Tak...     350453
# 22      Allium splendens Willd. ex Schult. & Schult.f.      18583
# 23               Smilacina davurica Fisch. & C.A. Mey.      58614
# 24               Corydalis gigantea Trautv. & C.A.Mey.     422189
# 25                      Astragalus schelichowii Turcz.     291178
# 26                 Lonicera maximowiczii (Rupr.) Regel     106030
# 27                                Sambucus racemosa L.       9060
# 28             Carex rigidioides (Gorodkov) V.I.Krecz.     199502
# 29        Abies nephrolepis (Trautv. ex Maxim.) Maxim.     429823
# ..                                                 ...        ...
# 143                            Campanula punctata Lam.     101961
# 144                             Carex ussuriensis Kom.     199952
# 145                  Moehringia lateriflora (L.) Fenzl     110809
# 146             Pseudostellaria sylvatica (Maxim.) Pax     111296
# 147                         Saussurea neoserrata Nakai     169440
# 148                              Luzula pallescens Sw.     265836
# 149              Acer ukurunduense Trautv. & C.A. Mey.     588172
# 150                   Weigela suavis (Kom.) L.H.Bailey     107629
# 151  Kitagawia terebinthacea (Fisch. ex Trevir.) Pi...     588202
# 152       Artemisia lagocephala (Fisch. ex Besser) DC.     125884
# 153                     Alnus fruticosa (Rupr.) Pouzar     588173
# 154  Dryopteris expansa (C. Presl) Fraser-Jenk. & J...     212819
# 155                           Rhododendron dauricum L.     224133
# 156                    Dryopteris fragrans (L.) Schott     212858
# 157   Diplazium sibiricum (Turcz. ex Kunze) Sa. Kurata      62611
# 158                 Parasenecio hastatus (L.) H.Koyama     164344
# 159                               Swida alba (L.) Opiz     588177
# 160                     Astragalus schelichowii Turcz.     291178
# 161                      Sedum middendorffianum Maxim.     588178
# 162                 Ribes palczewskii (Janch.) Pojark.     588164
# 163                         Paris verticillata M.Bieb.     350346
# 164                   Listera savatieri Maxim. ex Kom.     588179
# 165  Seseli seseloides (Fisch. & C.A. Mey. ex Turcz...     588165
only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123 entries, 3 to 172
# Data columns (total 35 columns):
# acronym                    123 non-null object
# additionals                123 non-null object
# altitude                   123 non-null object
# branch                     123 non-null object
# collection_finished        123 non-null object
# collection_started         123 non-null object
# collectors                 123 non-null object
# country                    123 non-null object
# country_id                 123 non-null int64
# created                    123 non-null object
# details                    123 non-null object
# dethistory                 123 non-null object
# devstage                   123 non-null object
# district                   123 non-null object
# family                     123 non-null object
# family_authorship          123 non-null object
# fieldid                    123 non-null object
# genus                      123 non-null object
# genus_authorship           123 non-null object
# gpsbased                   123 non-null bool
# id                         123 non-null int64
# identification_finished    123 non-null object
# identification_started     123 non-null object
# identifiers                123 non-null object
# itemcode                   123 non-null object
# latitude                   123 non-null float64
# longitude                  123 non-null float64
# note                       123 non-null object
# region                     123 non-null object
# species_authorship         123 non-null object
# species_epithet            123 non-null object
# species_fullname           123 non-null object
# species_id                 123 non-null int64
# species_status             123 non-null object
# updated                    123 non-null object
# dtypes: bool(1), float64(2), int64(3), object(29)
# memory usage: 33.8+ KB

# %% [markdown]
# Как оказалось, таких записей оказалось 123.

# %% [markdown]
# Найдем их среднюю высоту сбора:

# %%
print('Средняя высота сбора данных составляет {} м над уровнем моря'.format(altitude_only.altitude.astype(float).mean()))
# Out:
# Средняя высота сбора данных составляет 1065.0325203252032 м над уровнем моря

# %% [markdown]
# Для рассчёта средней высоты было использовано преобразование данных из строкового формата в числовой (с плавающей точкой). Это было сделано при помощи метода `.astype`; важно отметить, что такой подход может пройти не всегда, например, в случае интервально заданных высот, таких как "750-800",  следует применять более тонкие методы преобразования данных в числовой формат.

# %% [markdown]
# Добавим еще условия фильтрации: найдем данные, у которых определены высоты, большие километра, и которые были собраны в августе 2016 года.
#
# Для этого используем созданный DataFrame `altitude_only`, предварительно преобразовав его колонки `collection_started` и `altitude` к типам, описывающим даты и числа соответственно.

# %%
altitude_only.altitude = altitude_only.altitude.astype(float)
altitude_only.collection_started = pd.to_datetime(altitude_only.collection_started)

# %%
deadline = pd.to_datetime('2016-08-01')

# %%
altitude_only[(altitude_only.altitude > 1000) & (altitude_only.collection_started>deadline)]
# Out:
#     acronym additionals  altitude branch collection_finished  \
# 13     VBGI          []    1500.0
# 18     VBGI          []    1500.0
# 19     VBGI          []    1500.0
# 21     VBGI          []    1378.0
# 22     VBGI          []    1687.0                 2016-08-11
# 33     VBGI          []    1687.0                 2016-08-11
# 35     VBGI          []    1687.0
# 36     VBGI          []    1687.0
# 37     VBGI          []    1500.0
# 38     VBGI          []    1500.0
# 39     VBGI          []    1493.0
# 40     VBGI          []    1500.0
# 43     VBGI          []    1500.0
# 63     VBGI          []    1500.0
# 64     VBGI          []    1500.0
# 66     VBGI          []    1439.0
# 67     VBGI          []    1439.0
# 68     VBGI          []    1500.0
# 69     VBGI          []    1500.0
# 70     VBGI          []    1500.0
# 71     VBGI          []    1500.0
# 72     VBGI          []    1500.0
# 73     VBGI          []    1500.0
# 74     VBGI          []    1493.0
# 75     VBGI          []    1493.0
# 76     VBGI          []    1500.0
# 77     VBGI          []    1500.0
# 78     VBGI          []    1500.0
# 79     VBGI          []    1500.0
# 80     VBGI          []    1478.0
# 81     VBGI          []    1478.0
#                        species_authorship species_epithet  \
# 13                         Regel & Tiling       ajanensis
# 18                     Trautv. & C.A.Mey.   middendorffii
# 19                     Trautv. & C.A.Mey.   middendorffii
# 21   (Trautv. & C.A.Mey.) Takeda & Miyake    anticleoides
# 22          Willd. ex Schult. & Schult.f.       splendens
# 33              (Franch. & Sav.) Jacobsen           rosea
# 35                                 Maxim.    redowskianum
# 36                                 Maxim.    redowskianum
# 37                                    DC.        sibirica
# 38                                    DC.        sibirica
# 39                                   Kom.       tomentosa
# 40                                   Kom.       tomentosa
# 43                      Zdor. & Schapoval   woroschilowii
# 63                                    DC.        sibirica
# 64                   (L.) Asch. & Graebn.       canadense
# 66                          Fisch. ex DC.         radiata
# 67   (Trautv. & C.A.Mey.) Takeda & Miyake    anticleoides
# 68                       Fisch. ex Herder    spiraeifolia
# 69                     Trautv. & C.A.Mey.   middendorffii
# 70                    Trautv. & C.A. Mey.   middendorffii
# 71                                Burgsd.        sibirica
# 72   (Trautv. & C.A.Mey.) Takeda & Miyake    anticleoides
# 73                      Zdor. & Schapoval   woroschilowii
# 74                          Fisch. ex DC.         radiata
# 75                                   Kom.       tomentosa
# 76                             (L.) Nied.          alpina
# 77                                 Maxim.    redowskianum
# 78                          (Pall.) D.Don       ericoides
# 79                  (Sw.) Roem. & Schult.          alpina
# 80                              (L.) Bab.        caerulea
# 81                  (Sw.) Roem. & Schult.          alpina
# 82                                     L.      globularis
# 83                                   Kom.       tomentosa
# 107                        Regel & Tiling       ajanensis
# 108                        Regel & Tiling       ajanensis
# 109                     Zdor. & Schapoval   woroschilowii
# 110  (Trautv. & C.A.Mey.) Takeda & Miyake    anticleoides
# 111                         Fisch. ex DC.         radiata
# 112                         Fisch. ex DC.         radiata
# 113                   Trautv. & C.A. Mey.   middendorffii
# 114                                    L.      uliginosum
# 115                      Fisch. ex Herder    spiraeifolia
# 133                            (L.) Nied.          alpina
# 137                                    L.        farinosa
# 138                                    L.       palustris
# 139                                Maxim.    redowskianum
# 140                                   DC.       erianthum
# 141                      (Biehler) Fisch.        gmelinii
# 171         Willd. ex Schult. & Schult.f.       splendens
# 172             (Franch. & Sav.) Jacobsen           rosea
#
#                                       species_fullname species_id  \
# 13                   Tilingia ajanensis Regel & Tiling      34270
# 18       Hemerocallis middendorffii Trautv. & C.A.Mey.     585041
# 19       Hemerocallis middendorffii Trautv. & C.A.Mey.     585041
# 21   Veratrum anticleoides (Trautv. & C.A.Mey.) Tak...     350453
# 22      Allium splendens Willd. ex Schult. & Schult.f.      18583
# 33            Rhodiola rosea (Franch. & Sav.) Jacobsen     190849
# 35                    Rhododendron redowskianum Maxim.     224959
# 36                    Rhododendron redowskianum Maxim.     224959
# 37                              Ligularia sibirica DC.     159894
# 38                              Ligularia sibirica DC.     159894
# 39                            Saussurea tomentosa Kom.     169678
# 40                            Saussurea tomentosa Kom.     169678
# 43               Aster woroschilowii Zdor. & Schapoval     127224
# 63                              Ligularia sibirica DC.     159894
# 64   Chamaepericlymenum canadense (L.) Asch. & Graebn.     588184
# 66                    Scorzonera radiata Fisch. ex DC.     170104
# 67   Veratrum anticleoides (Trautv. & C.A.Mey.) Tak...     350453
# 68              Solidago spiraeifolia Fisch. ex Herder     174602
# 69       Hemerocallis middendorffii Trautv. & C.A.Mey.     585041
# 70            Betula middendorffii Trautv. & C.A. Mey.     588182
# 71                          Juniperus sibirica Burgsd.     588185
# 72   Veratrum anticleoides (Trautv. & C.A.Mey.) Tak...     350453
# 73               Aster woroschilowii Zdor. & Schapoval     127224
# 74                    Scorzonera radiata Fisch. ex DC.     170104
# 75                            Saussurea tomentosa Kom.     169678
# 76                           Arctous alpina (L.) Nied.     220205
# 77                    Rhododendron redowskianum Maxim.     224959
# 78                    Cassiope ericoides (Pall.) D.Don     220479
# 79             Hierochloe alpina (Sw.) Roem. & Schult.     450128
# 80                       Phyllodoce caerulea (L.) Bab.     223519
# 81             Hierochloe alpina (Sw.) Roem. & Schult.     450128
# 82                                 Carex globularis L.     198400
# 83                            Saussurea tomentosa Kom.     169678
# 107                  Tilingia ajanensis Regel & Tiling      34270
# 108                  Tilingia ajanensis Regel & Tiling      34270
# 109              Aster woroschilowii Zdor. & Schapoval     127224
# 110  Veratrum anticleoides (Trautv. & C.A.Mey.) Tak...     350453
# 111                   Scorzonera radiata Fisch. ex DC.     170104
# 112                   Scorzonera radiata Fisch. ex DC.     170104
# 113           Betula middendorffii Trautv. & C.A. Mey.     588182
# 114                            Vaccinium uliginosum L.     226563
# 115             Solidago spiraeifolia Fisch. ex Herder     174602
# 133                          Arctous alpina (L.) Nied.     220205
# 137                                Primula farinosa L.     479002
# 138                             Parnassia palustris L.     115798
# 139                   Rhododendron redowskianum Maxim.     224959
# 140                             Geranium erianthum DC.     242710
# 141               Adenophora gmelinii (Biehler) Fisch.     101301
# 171     Allium splendens Willd. ex Schult. & Schult.f.      18583
# 172           Rhodiola rosea (Franch. & Sav.) Jacobsen     190849
#
#      species_status     updated
# 13   From plantlist  2017-06-13
# 18   From plantlist  2017-06-13
# 19   From plantlist  2017-06-13
# 21   From plantlist  2017-06-13
# 22   From plantlist  2017-06-13
# 33   From plantlist  2017-06-13
# 35   From plantlist  2017-06-13
# 36   From plantlist  2017-06-13
# 37   From plantlist  2017-06-13
# 38   From plantlist  2017-06-13
# 39   From plantlist  2017-06-13
# 40   From plantlist  2017-06-13
# 43   From plantlist  2017-06-13
# 63   From plantlist  2017-06-13
# 64   From plantlist  2017-06-13
# 66   From plantlist  2017-06-13
# 67   From plantlist  2017-06-13
# 68   From plantlist  2017-06-13
# 69   From plantlist  2017-06-13
# 70   From plantlist  2017-06-13
# 71   From plantlist  2017-06-13
# 72   From plantlist  2017-06-13
# 73   From plantlist  2017-06-13
# 74   From plantlist  2017-06-13
# 75   From plantlist  2017-06-13
# 76   From plantlist  2017-06-13
# 77   From plantlist  2017-06-13
# 78   From plantlist  2017-06-13
# 79   From plantlist  2017-06-13
# 80   From plantlist  2017-06-13
# 81   From plantlist  2017-06-13
# 82   From plantlist  2017-06-13
# 83   From plantlist  2017-06-13
# 107  From plantlist  2017-06-13
# 108  From plantlist  2017-06-13
# 109  From plantlist  2017-06-13
# 110  From plantlist  2017-06-13
# 111  From plantlist  2017-06-13
# 112  From plantlist  2017-06-13
# 113  From plantlist  2017-06-13
# 114  From plantlist  2017-06-13
# 115  From plantlist  2017-06-13
# 133  From plantlist  2017-06-13
# 137  From plantlist  2017-06-13
# 138  From plantlist  2017-06-13
# 139  From plantlist  2017-06-13
# 140  From plantlist  2017-06-13
# 141  From plantlist  2017-06-13
# 171  From plantlist  2017-06-13
# 172  From plantlist  2017-06-13
#
# [50 rows x 35 columns]

# %% [markdown]
# ### Сложные запросы

# %% [markdown]
# В текущей редакции HTTP API (см. Описание) электронного гербария не поддерживает запросы типа "ИЛИ", т.е. путем задания поискового URI невозможно задать, например, такой запрос: Найти все образцы, у которых дата сбора была либо весной, либо осенью 2016 года.
# Однако, такие запросы легко выполнить разбив их на несколько последовательных запросов с последующей склейкой результатов средствами пакета `Pandas` (проблема, связанная с "большими данными" в этом случе не возникнет, поскольку вряд ли приходится ожидать, что объем базы данных будет превышать, например, 10М записей).
#
# Приведем пример формирования 'ИЛИ' запроса с последующей склейкой результатов.
# Для этого рассмотрим пару посковых запросов `search_query1` и `search_query2`, и скомбинируем их, чтобы получить результаты, удовлетворяющие либо первому, либо второму запросу (т.е. `search_query1` OR `search_query2`):

# %%
search_query1 = (('collectedby', 'Крестов'),
                 ('identifiedby', 'Крестов') 
                 )
search_query2 = (('collectedby', 'Баркалов'),
                 ('identifiedby', 'Пименова')
                 )

# %%
from functools import reduce # `reduce` was moved into functools in Python3

# Make search queries consequently...
datastore = []
for sp in [search_query1, search_query2]:
    search_request_url = HERBARIUM_SEARCH_URL + '?' + '&'.join(map(lambda x: x[0] + '=' + quote(x[1].strip()), sp))
    server_response = urlopen(search_request_url)
    data = json.loads(server_response.read().decode('utf-8'))
    data = pd.DataFrame(data['data'])
    datastore.append(data)
    server_response.close()

# Combine the result using Pandas:
df_combined = pd.concat(datastore).drop_duplicates('id').reset_index()

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Data columns (total 36 columns):
# index                      519 non-null int64
# acronym                    519 non-null object
# additionals                519 non-null object
# altitude                   519 non-null object
# branch                     519 non-null object
# collection_finished        519 non-null object
# collection_started         519 non-null object
# collectors                 519 non-null object
# country                    519 non-null object
# country_id                 517 non-null float64
# created                    519 non-null object
# details                    519 non-null object
# dethistory                 519 non-null object
# devstage                   519 non-null object
# district                   519 non-null object
# family                     519 non-null object
# family_authorship          519 non-null object
# fieldid                    519 non-null object
# genus                      519 non-null object
# genus_authorship           519 non-null object
# gpsbased                   519 non-null bool
# id                         519 non-null int64
# identification_finished    519 non-null object
# identification_started     519 non-null object
# identifiers                519 non-null object
# itemcode                   519 non-null object
# latitude                   519 non-null float64
# longitude                  519 non-null float64
# note                       519 non-null object
# region                     519 non-null object
# species_authorship         519 non-null object
# species_epithet            519 non-null object
# species_fullname           519 non-null object
# species_id                 519 non-null int64
# species_status             519 non-null object
# updated                    519 non-null object
# dtypes: bool(1), float64(3), int64(3), object(29)
# memory usage: 142.5+ KB

# %%
df_combined.shape
# Out:
# (519, 36)

# %% [markdown]
# Исходные размерности запросов:

# %%
datastore[0].shape, datastore[1].shape
# Out:
# ((175, 35), (346, 35))

# %% [markdown]
# ## Поиск в полигональных областях

# %% [markdown]
# При формировании запросов о месте сбора можно только указывать прямоугольные области, в которых выполняется поиск. Это связано прежде всего с тем, что система управления базой данных, работающая на сервере, не поддерживает географических запросов. Тем не менее, поиск по области достаточно просто эмулировать средствами языка программировния `Python`, с помощью какого-либо пакета для обработки географических данных.

# %% [markdown]
# Рассмотрим задачу сравнения флор о. Сахалин и полуострова Камчатка. Для этого будем работать с shp-файлами, представляющими контура данных территорий.
# Для работы с shp-файлами в Python потребуется установить пакет pyshp, а также нам будет удобен пакет shapely -- для работы с географически распределенными данными.

# %% [markdown]
# Если предположить, что в текущем каталоге, где запускается скрипт Python, находится папка с shаpe-файлами, то чтение данных из таких файлов будет выглядеть следующим образом:

# %%
import shapefile
import numpy as np # Note: numpy is a part of Pandas pack: you can access numpy via pandas.np or pd.np

sakhalin_shp = shapefile.Reader("shapefiles/sakhalin.shp")

# %% [markdown]
# Преобразуем данные из прочитанного файла в numpy массив координат точек контура. Это необходимо для удобства визуализации с помощью пакета matplotlib.

# %%
contour_sakhalin = np.array(sakhalin_shp.shapes()[0].points)

# %% [markdown]
# Удостоверимся, что загруженный контур действительно представляет собой о. Сахалин:

# %%
from pylab import *
plot(contour_sakhalin[:,0], contour_sakhalin[:,1])
gca().set_aspect('equal')
title('Sakhalin Island')
show()

# %% [markdown]
# Контур представлен 835 точками.

# %%
contour_sakhalin.shape
# Out:
# (835, 2)

# %% [markdown]
# Ограничивающий область прямоугольник легко может быть найден из спецификации shape-файла:

# %%
sakhalin_shp.bbox
# Out:
# [141.63803100585938, 45.88860321044922, 144.75164794921875, 54.424713134765625]

# %% [markdown]
# В соответствии с формой поисковых запросов, создадим запрос к базе данных

# %%
query_sakhalin_bbox = tuple(zip(['lonl', 'latl', 'lonu', 'latu'], map(str, sakhalin_shp.bbox)))
print(query_sakhalin_bbox)
# Out:
# (('lonl', '141.63803100585938'), ('latl', '45.88860321044922'), ('lonu', '144.75164794921875'), ('latu', '54.424713134765625'))

# %%
within_sakhalin_request_url = HERBARIUM_SEARCH_URL + '?' + '&'.join(map(lambda x: x[0] + '=' + quote(x[1].strip()), query_sakhalin_bbox))

# %%
within_sakhalin_request_url
# Out:
# 'http://botsad.ru/hitem/json/?lonl=141.63803100585938&latl=45.88860321044922&lonu=144.75164794921875&latu=54.424713134765625'

# %% [markdown]
# Получение данных:

# %%
server_response = urlopen(within_sakhalin_request_url)
sakhalin_data_in_bbox = pd.DataFrame(json.loads(server_response.read().decode('utf-8'))['data'])
